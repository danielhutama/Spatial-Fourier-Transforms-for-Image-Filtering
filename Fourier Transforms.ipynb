# %%
from scipy import fftpack, ndimage
import numpy as np
from imageio import imread
from matplotlib import pyplot as plt

img = imread('PeriodicRectangles.png')
f = np.fft.fft2(img, norm='ortho')
fshift = np.fft.fftshift(f)
power = (np.abs(fshift).astype(np.uint8))**2
magnitude_spectrum = np.abs(fshift).astype(np.uint8)
phase = np.angle(fshift).astype(np.uint8)


l1, l2, font, s1, s2, padding = 3.0, 10.0, 25.0, 20.0, 10.0, 10.0
fig = plt.figure('mydata', figsize = (s1,s2))
plt.rcParams.update({'font.size': font})
ax = fig.add_subplot(111)
ax.ticklabel_format(style = 'sci', scilimits=(-2,3),axis='y')
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(l1)
    ax.xaxis.set_tick_params(width=l1, length = l2, pad=padding)
    ax.yaxis.set_tick_params(width=l1, length = l2, pad=padding)
    
    
plt.subplot(121), plt.imshow(img, cmap = 'gray')
# plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.title('Input Image')

plt.subplot(122),plt.imshow(power, cmap = 'gray')
# plt.title('Power Spectrum'), plt.xticks([]), plt.yticks([])
plt.title('Power Spectrum')
plt.show()

l1, l2, font, s1, s2, padding = 3.0, 10.0, 25.0, 20.0, 10.0, 10.0
fig = plt.figure('mydata', figsize = (s1,s2))
plt.rcParams.update({'font.size': font})
ax = fig.add_subplot(111)
ax.ticklabel_format(style = 'sci', scilimits=(-2,3),axis='y')
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(l1)
    ax.xaxis.set_tick_params(width=l1, length = l2, pad=padding)
    ax.yaxis.set_tick_params(width=l1, length = l2, pad=padding)

plt.subplot(121),plt.imshow(magnitude_spectrum, cmap = 'gray')
# plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.title('Magnitude Spectrum')


plt.subplot(122),plt.imshow(phase, cmap='gray')
# plt.title('Phase Spectrum'), plt.xticks([]), plt.yticks([])
plt.title('Phase Spectrum')
plt.show()

# %%
restored = np.fft.ifftshift(fshift)
f2 = np.fft.ifft2(restored)
magnitude_spectrum2 = np.abs(f2).astype(np.uint8)

l1, l2, font, s1, s2, padding = 3.0, 10.0, 25.0, 20.0, 10.0, 10.0
fig = plt.figure('mydata', figsize = (s1,s2))
plt.rcParams.update({'font.size': font})
ax = fig.add_subplot(111)
ax.ticklabel_format(style = 'sci', scilimits=(-2,3),axis='y')
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(l1)
    ax.xaxis.set_tick_params(width=l1, length = l2, pad=padding)
    ax.yaxis.set_tick_params(width=l1, length = l2, pad=padding)

    
plt.subplot(121), plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(magnitude_spectrum2, cmap = 'gray', interpolation = 'nearest')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
shiftedmag = np.fft.ifftshift(magnitude_spectrum)
f3 = np.fft.ifft2(shiftedmag)
magnitude_spectrum3 = np.abs(f3).astype(np.uint8)

l1, l2, font, s1, s2, padding = 3.0, 10.0, 25.0, 20.0, 10.0, 10.0
fig = plt.figure('mydata', figsize = (s1,s2))
plt.rcParams.update({'font.size': font})
ax = fig.add_subplot(111)
ax.ticklabel_format(style = 'sci', scilimits=(-2,3),axis='y')
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(l1)
    ax.xaxis.set_tick_params(width=l1, length = l2, pad=padding)
    ax.yaxis.set_tick_params(width=l1, length = l2, pad=padding)

    
plt.subplot(121), plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(magnitude_spectrum3, cmap = 'gray', interpolation = 'nearest')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
l1, l2, font, s1, s2, padding = 3.0, 10.0, 25.0, 20.0, 20.0, 10.0
fig = plt.figure('mydata', figsize = (s1,s2))
plt.rcParams.update({'font.size': font})
ax = fig.add_subplot(111)
ax.ticklabel_format(style = 'sci', scilimits=(-2,3),axis='y')
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(l1)
    ax.xaxis.set_tick_params(width=l1, length = l2, pad=padding)
    ax.yaxis.set_tick_params(width=l1, length = l2, pad=padding)
    
    
# plt.subplot(121), plt.imshow(img, cmap = 'gray')
# plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
